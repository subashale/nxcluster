# %%
from ncomponent import NComponent as nc

# %%
init_G = nc(cluster=[15, 15, 15], degree=3, n_bridge=2)
init_G.create()
init_G.draw_graph()

# %%
init_G = nc(cluster=3, node=15, degree=3, n_bridge=2)
init_G.create()
init_G.draw_graph()

# %%
init_G.remove_edge(n_remove=2)
init_G.draw_graph()
